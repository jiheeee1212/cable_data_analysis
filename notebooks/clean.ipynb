# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.load import load_csv,load_pickle
from src.config import RAW_MART_PATH,RAW_LOG_PATH,INTERIM_MART_PATH
from src.clean import (
    drop_high_null_cols,
    drop_unused_mart_cols,
    drop_unused_log_cols,
    get_column_summary,
    clean_mart,
    clean_log
)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
mart_df = load_csv(RAW_MART_PATH)
mart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470064 entries, 0 to 470063
# Data columns (total 88 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   asset_id            470064 non-null  object
#  1   actr_disp           470060 non-null  object
#  2   asset_nm            470064 non-null  object
#  3   asset_prod          470064 non-null  object
#  4   aud                 0 non-null       float64
#  5   audience_cnt        0 non-null       float64
#  6   broad_ymd           466682 non-null  object
#  7   category            468827 non-null  object
#  8   chapter             468852 non-null  object
#  9   created             470064 non-null  int64
#  10  created_by          470064 non-null  object
#  11  crt_ymd             467690 non-null  object
#  12  ct_cl               470064 non-null  object
#  13  cts_id              468751 non-null  object
#  14  description         470064 non-null  object
#  15  director            470036 non-null  object
#  16  disp_as_lst_chnc    3575 non-null    float64
#  17  disp_as_new         3575 non-null    float64
#  18  disp_rtm            470064 non-null  object
#  19  dsbtr_nm            0 non-null       float64
#  20  epsd_id             469976 non-null  object
#  21  epsd_nm             470064 non-null  object
#  22  epsd_no             469720 non-null  float64
#  23  full_asset_id       470064 non-null  object
#  24  genre               470064 non-null  object
#  25  genre_of_ct_cl      470064 non-null  object
#  26  genre_of_ct_cl_cd   470064 non-null  int64
#  27  grade_score         0 non-null       float64
#  28  hash_tag            0 non-null       float64
#  29  img_base_dir        468436 non-null  object
#  30  is_hot_fl           467340 non-null  float64
#  31  is_new_fl           467340 non-null  float64
#  32  long_tail_fl        468858 non-null  float64
#  33  lt_inclsn_fl        470064 non-null  int64
#  34  mobile_watch_url    0 non-null       float64
#  35  one_line_review     0 non-null       float64
#  36  orgnl_air_dt        0 non-null       float64
#  37  orgnl_cntry         469996 non-null  object
#  38  poster_del_fl       470064 non-null  int64
#  39  poster_pt           469081 non-null  object
#  40  prdcrs              1 non-null       object
#  41  preview_file_nm     13994 non-null   object
#  42  preview_rate        13994 non-null   float64
#  43  preview_rtm         13994 non-null   object
#  44  prevw_prd           470064 non-null  int64
#  45  product_tp          470042 non-null  float64
#  46  provider            470064 non-null  object
#  47  prpgt_pri           470064 non-null  int64
#  48  prvd_id             470064 non-null  object
#  49  publctn_rt          468558 non-null  object
#  50  rate                470064 non-null  int64
#  51  rlse_year           470059 non-null  float64
#  52  rvsn_id             470064 non-null  int64
#  53  screen_tp           470053 non-null  object
#  54  seasn_fin_fl        3575 non-null    float64
#  55  seasn_prem_fl       2369 non-null    float64
#  56  series_sq           358292 non-null  float64
#  57  show_tp             0 non-null       float64
#  58  smry                470012 non-null  object
#  59  smry_lng            470014 non-null  object
#  60  smry_shrt           470014 non-null  object
#  61  sp_id               470031 non-null  object
#  62  star_score          0 non-null       float64
#  63  studio              469065 non-null  object
#  64  studio_cd           91316 non-null   object
#  65  studio_nm           468976 non-null  object
#  66  sub_title           0 non-null       float64
#  67  super_asset_id      469068 non-null  object
#  68  super_asset_nm      468718 non-null  object
#  69  super_asset_sq      467745 non-null  float64
#  70  svc_applied         17152 non-null   float64
#  71  svc_apy_fl          470031 non-null  float64
#  72  thmbnl_del_fl       470031 non-null  float64
#  73  thmbnl_fl           458013 non-null  float64
#  74  thmbnl_pt           455296 non-null  object
#  75  thmbnl_rep_file_nm  455296 non-null  object
#  76  ttl                 469958 non-null  object
#  77  ttl_brief           470031 non-null  object
#  78  ttl_lng             2369 non-null    object
#  79  ttl_mdm             2385 non-null    object
#  80  ttl_sort_nm         3920 non-null    object
#  81  updated             470031 non-null  float64
#  82  use_fl              470031 non-null  float64
#  83  ver_major           470031 non-null  float64
#  84  ver_minor           470031 non-null  float64
#  85  vod_acq_tp_cd       470031 non-null  object
#  86  wrtr_disp           467494 non-null  object
#  87  asset_5             470064 non-null  object
# dtypes: float64(32), int64(8), object(48)
# memory usage: 315.6+ MB

# %%
mart_df, dropped_by_null = drop_high_null_cols(mart_df, threshold=90)

print(f"Dropped {len(dropped_by_null)}")
dropped_by_null
# Out:
# Dropped 23
# ['aud',
#  'audience_cnt',
#  'disp_as_lst_chnc',
#  'disp_as_new',
#  'dsbtr_nm',
#  'grade_score',
#  'hash_tag',
#  'mobile_watch_url',
#  'one_line_review',
#  'orgnl_air_dt',
#  'prdcrs',
#  'preview_file_nm',
#  'preview_rate',
#  'preview_rtm',
#  'seasn_fin_fl',
#  'seasn_prem_fl',
#  'show_tp',
#  'star_score',
#  'sub_title',
#  'svc_applied',
#  'ttl_lng',
#  'ttl_mdm',
#  'ttl_sort_nm']

# %%
mart_df = drop_unused_mart_cols(mart_df)

# %%
col_summary = get_column_summary(mart_df)
col_summary
# Out:
#                column    dtype  null_cnt  null_rate  unique_cnt
# 0           actr_disp   object         4       0.00       41757
# 1            asset_nm   object         0       0.00      360181
# 2          asset_prod   object         0       0.00           3
# 3           broad_ymd   object      3382       0.72       10575
# 4            category   object      1237       0.26       20122
# 5             created    int64         0       0.00      465546
# 6          created_by   object         0       0.00          11
# 7             crt_ymd   object      2374       0.51        2218
# 8               ct_cl   object         0       0.00          15
# 9              cts_id   object      1313       0.28      468747
# 10            epsd_id   object        88       0.02      305144
# 11            epsd_no  float64       344       0.07        2546
# 12      full_asset_id   object         0       0.00      470064
# 13              genre   object         0       0.00          80
# 14     genre_of_ct_cl   object         0       0.00          59
# 15  genre_of_ct_cl_cd    int64         0       0.00          18
# 16       lt_inclsn_fl    int64         0       0.00           2
# 17         product_tp  float64        22       0.00           8
# 18          prpgt_pri    int64         0       0.00          11
# 19         publctn_rt   object      1506       0.32           8
# 20               rate    int64         0       0.00           5
# 21          rlse_year  float64         5       0.00         100
# 22          screen_tp   object        11       0.00           3
# 23          studio_nm   object      1088       0.23        5002
# 24     super_asset_id   object       996       0.21      282852

# %%
clean_mart_df = clean_mart(mart_df)

# %%
clean_mart_summary = get_column_summary(clean_mart_df)
clean_mart_summary
# Out:
#                column           dtype  null_cnt  null_rate  unique_cnt
# 0           actr_disp        category         4       0.00       41757
# 1            asset_nm        category         0       0.00      360181
# 2          asset_prod        category         0       0.00           3
# 3           broad_ymd  datetime64[ns]      3385       0.72       10572
# 4            category        category      1237       0.26       20122
# 5             created  datetime64[ns]         0       0.00      465546
# 6          created_by        category         0       0.00          11
# 7             crt_ymd  datetime64[ns]      2724       0.58        2184
# 8               ct_cl        category         0       0.00          15
# 9              cts_id        category      1313       0.28      468747
# 10            epsd_id        category        88       0.02      305144
# 11            epsd_no        category       344       0.07        2546
# 12      full_asset_id        category         0       0.00      470064
# 13              genre        category         0       0.00          80
# 14     genre_of_ct_cl        category         0       0.00          59
# 15  genre_of_ct_cl_cd           int64         0       0.00          18
# 16       lt_inclsn_fl           int64         0       0.00           1
# 17         product_tp           Int64        22       0.00           8
# 18          prpgt_pri        category         0       0.00          11
# 19         publctn_rt        category      1506       0.32           8
# 20               rate           int64         0       0.00           5
# 21          rlse_year  datetime64[ns]         5       0.00         100
# 22          screen_tp        category        11       0.00           3
# 23          studio_nm        category      1088       0.23        5002
# 24     super_asset_id        category       996       0.21      282852

# %%
clean_mart_df.head(3)
# Out:
#   actr_disp    asset_nm asset_prod broad_ymd              category  \
# 0   양택조,김영환       건강 체조        FOD       NaT     지역콘텐츠/CCS충북/건강 체조
# 1         -  자연을 닮은 농부들        FOD       NaT  지역콘텐츠/CCS충북/의림지뜰 사람들
# 2         -      가을의 추억        FOD       NaT  지역콘텐츠/CCS충북/의림지뜰 사람들
#
#                         created   created_by    crt_ymd ct_cl     cts_id  \
# 0 1970-01-01 05:36:51.126152916  VODIN:2.0.3 2021-11-26    기타  CCS000001
# 1 1970-01-01 05:36:51.223151741  VODIN:2.0.3 2021-12-23    기타  CCS000006
# 2 1970-01-01 05:36:51.225171925  VODIN:2.0.3 2021-12-25    기타  CCS000007
#
#       epsd_id epsd_no             full_asset_id genre genre_of_ct_cl  \
# 0     건강 체조_1     1.0  CCS|CCS00000000000000101    기타             기타
# 1  의림지뜰 사람들_1     1.0  CCS|CCS00000000000000601    다큐             기타
# 2  의림지뜰 사람들_2     2.0  CCS|CCS00000000000000701    다큐             기타
#
#    genre_of_ct_cl_cd  lt_inclsn_fl  product_tp prpgt_pri publctn_rt  rate  \
# 0                  0             0          10         1         TV     0
# 1                  0             0          10         1         TV    15
# 2                  0             0          10         1         TV    15
#
#                       rlse_year screen_tp studio_nm super_asset_id
# 0 1970-01-01 00:00:00.000002010        HD   CCS충북방송     null-00001
# 1 1970-01-01 00:00:00.000002021        HD   CCS충북방송     null-00001
# 2 1970-01-01 00:00:00.000002021        HD   CCS충북방송     null-00002

# %%
clean_mart_df['publctn_rt'].unique()
# Out:
# ['TV', NaN, 'TV,인터넷,모바일', 'TV,모바일', 'TV,모바일,인터넷', 'TV,인터넷', 'TV,TV,모바일,모바일,인터넷,인터넷', '모바일,인터넷', 'TV,TV']
# Categories (8, object): ['TV', 'TV,TV', 'TV,TV,모바일,모바일,인터넷,인터넷', 'TV,모바일', 'TV,모바일,인터넷', 'TV,인터넷', 'TV,인터넷,모바일', '모바일,인터넷']

# %%
interim_path = "../data/interim/interim_mart.pkl"
clean_mart_df.to_pickle(interim_path)

print(f" 파일 저장 완료: {interim_path}")
# Out:
#  파일 저장 완료: ../data/interim/interim_mart.pkl

# %%
from src.load import load_pickle

# %%
log_df  = load_pickle(RAW_LOG_PATH)

# %%
log_df.head(10)
# Out:
#                                            sha2_hash  \
# 0  992c0dd6bafc5df33e86ece4885d574d25288d06530c65...
# 1  ea62338ac5b6b11cf02ef8bf1889d1a063cec2c2493937...
# 2  36aa302f3705794f5c2e5a971f38c8ef3c5a789e915c94...
# 3  d1ff76342bbc4f23f82c318b1f7a0ffc78f0b5ad2d1314...
# 4  8cf3e070a173520f59e24b246ef83a1140c26d260c4ddd...
# 5  7989cd8e8272b9dbfe94a7253809a7d64d22ce0449ca45...
# 6  6c2fcacab6bba01b83d912bb6241f00d0296a3dd9b3add...
# 7  6939dee90e40ace55463b17e418084f13f5262886aec3e...
# 8  2b365d07914ab58d3a99e014ba7bc24f0ea7335ecf24cb...
# 9  158e438e7d68ed90deb7dd3bc747ac552ba5a9032071a3...
#
#                       asset                   asset_nm     CT_CL  \
# 0  cjc|M4767613LSGK41566601                 날 녹여주오 04회     TV드라마
# 1  cjc|M5140475LSGL08601501                        압꾸정        영화
# 2  cjc|M5079740LSVK14589601                 어웨이크(2021)        영화
# 3  cjc|M4574740LFOL08934201          동글동글 동물친구 시즌2 01회        키즈
# 4  cjc|M5055522LFOI39238101    1박2일 시즌4 127회(22/05/29)  TV 연예/오락
# 5  cjc|M4818070LSVH73774901                  학려화정 60회.     TV드라마
# 6  cjc|M5148050LSGL25460601                (할인)탑건: 매버릭        영화
# 7  cjc|M5042788LSGL28317101     (HD)런닝맨 638회(23/01/22)  TV 연예/오락
# 8  cjc|M5035408LFOJ17822601    (HD)복면가왕 367회(22/07/31)  TV 연예/오락
# 9  cjc|M5010409LSVI64860301  (더빙)겜브링TV NEW 어드벤처 06회(G)   TV애니메이션
#
#   genre_of_ct_cl  use_tms disp_rtm             strt_dt  \
# 0         외화 시리즈   3660.0    01:01 2023-01-23 17:08:58
# 1            코미디      2.0    01:51 2023-01-23 22:28:46
# 2         공포/스릴러      7.0    01:14 2023-01-23 21:09:40
# 3             기타     60.0    00:01 2023-01-23 09:05:10
# 4             기타    157.0    01:19 2023-01-23 21:30:28
# 5         외화 시리즈      7.0    00:42 2023-01-23 03:24:27
# 6        액션/어드벤쳐   7571.0    02:10 2023-01-23 19:26:08
# 7             기타   5280.0    01:28 2023-01-23 10:16:48
# 8             기타   5079.0    01:25 2023-01-23 19:29:43
# 9             기타   1140.0    00:19 2023-01-23 10:01:47
#
#                            category
# 0             CJ ENM/CJENM구작/날 녹여주오
# 1                    영화/(HD)극장동시상영관
# 2                영화월정액관/무비n시리즈/범죄공포
# 3       키즈어린이/영어-놀이학습/동글동글 동물친구 시즌2
# 4         KBS/(HD)KBS 연예오락/1박2일 시즌4
# 5                 해외드라마/무비n시리즈/학려화정
# 6                      오늘의추천/반값할인관1
# 7          SBS/(HD)SBS 연예오락/(HD)런닝맨
# 8         MBC/(HD)MBC 연예오락/(HD)복면가왕
# 9  애니메이션/게임애니팩토리/(더빙)겜브링TV NEW 어드벤처

# %%
log_df_summary = get_column_summary(log_df)
log_df_summary
# Out:
#            column           dtype  null_cnt  null_rate  unique_cnt
# 0       sha2_hash          object         0       0.00      817119
# 1           asset          object     13997       0.03      439170
# 2        asset_nm          object   1157048       2.28      340030
# 3           CT_CL          object   1157048       2.28          15
# 4  genre_of_ct_cl          object   1157048       2.28          59
# 5         use_tms         float64         1       0.00       20494
# 6        disp_rtm          object   1157048       2.28         359
# 7         strt_dt  datetime64[ns]         1       0.00    17365219
# 8        category          object   1183154       2.33       19419

# %%
log_df= drop_unused_log_cols(log_df)

# %%
clean_log_df = clean_log(log_df)

# %%
clean_log_summary = get_column_summary(clean_log_df)
clean_log_summary
# Out:
#          column           dtype  null_cnt  null_rate  unique_cnt
# 0     sha2_hash        category         0       0.00      817119
# 1         asset        category     13997       0.03      439170
# 2       use_tms           Int64         1       0.00       20494
# 3       strt_dt  datetime64[ns]         1       0.00    17365219
# 4  disp_rtm_sec           Int64   1157048       2.28         352

# %%
interim_path = "../data/interim/interim_log.pkl"
clean_log_df.to_pickle(interim_path)

print(f" 파일 저장 완료: {interim_path}")
# Out:
#  파일 저장 완료: ../data/interim/interim_log.pkl

# %% [markdown]
# - interim

# %%
from src.load import load_interim_file

# %%
interim_mart = load_interim_file(file_type="mart")

# %%
interim_log = load_interim_file(file_type="log")

# %%
interim_log.head(10)
# Out:
#                                            sha2_hash  \
# 0  992c0dd6bafc5df33e86ece4885d574d25288d06530c65...
# 1  ea62338ac5b6b11cf02ef8bf1889d1a063cec2c2493937...
# 2  36aa302f3705794f5c2e5a971f38c8ef3c5a789e915c94...
# 3  d1ff76342bbc4f23f82c318b1f7a0ffc78f0b5ad2d1314...
# 4  8cf3e070a173520f59e24b246ef83a1140c26d260c4ddd...
# 5  7989cd8e8272b9dbfe94a7253809a7d64d22ce0449ca45...
# 6  6c2fcacab6bba01b83d912bb6241f00d0296a3dd9b3add...
# 7  6939dee90e40ace55463b17e418084f13f5262886aec3e...
# 8  2b365d07914ab58d3a99e014ba7bc24f0ea7335ecf24cb...
# 9  158e438e7d68ed90deb7dd3bc747ac552ba5a9032071a3...
#
#                       asset  use_tms             strt_dt  disp_rtm_sec
# 0  cjc|M4767613LSGK41566601     3660 2023-01-23 17:08:58            61
# 1  cjc|M5140475LSGL08601501        2 2023-01-23 22:28:46           111
# 2  cjc|M5079740LSVK14589601        7 2023-01-23 21:09:40            74
# 3  cjc|M4574740LFOL08934201       60 2023-01-23 09:05:10             1
# 4  cjc|M5055522LFOI39238101      157 2023-01-23 21:30:28            79
# 5  cjc|M4818070LSVH73774901        7 2023-01-23 03:24:27            42
# 6  cjc|M5148050LSGL25460601     7571 2023-01-23 19:26:08           130
# 7  cjc|M5042788LSGL28317101     5280 2023-01-23 10:16:48            88
# 8  cjc|M5035408LFOJ17822601     5079 2023-01-23 19:29:43            85
# 9  cjc|M5010409LSVI64860301     1140 2023-01-23 10:01:47            19

# %%
interim_log_summary = get_column_summary(interim_log)
interim_log_summary
# Out:
#          column           dtype  null_cnt  null_rate  unique_cnt
# 0     sha2_hash        category         0       0.00      817119
# 1         asset        category     13997       0.03      439170
# 2       use_tms           Int64         1       0.00       20494
# 3       strt_dt  datetime64[ns]         1       0.00    17365219
# 4  disp_rtm_sec           Int64   1157048       2.28         352

# %%
interim_mart_summary = get_column_summary(interim_mart)
interim_mart_summary
# Out:
#                column           dtype  null_cnt  null_rate  unique_cnt
# 0           actr_disp        category         4       0.00       41757
# 1            asset_nm        category         0       0.00      360181
# 2          asset_prod        category         0       0.00           3
# 3           broad_ymd  datetime64[ns]      3385       0.72       10572
# 4            category        category      1237       0.26       20122
# 5             created  datetime64[ns]         0       0.00      465546
# 6          created_by        category         0       0.00          11
# 7             crt_ymd  datetime64[ns]      2724       0.58        2184
# 8               ct_cl        category         0       0.00          15
# 9              cts_id        category      1313       0.28      468747
# 10            epsd_id        category        88       0.02      305144
# 11            epsd_no        category       344       0.07        2546
# 12      full_asset_id        category         0       0.00      470064
# 13              genre        category         0       0.00          80
# 14     genre_of_ct_cl        category         0       0.00          59
# 15  genre_of_ct_cl_cd           int64         0       0.00          18
# 16       lt_inclsn_fl           int64         0       0.00           1
# 17         product_tp           Int64        22       0.00           8
# 18          prpgt_pri        category         0       0.00          11
# 19         publctn_rt        category      1506       0.32           8
# 20               rate           int64         0       0.00           5
# 21          rlse_year  datetime64[ns]         5       0.00         100
# 22          screen_tp        category        11       0.00           3
# 23          studio_nm        category      1088       0.23        5002
# 24     super_asset_id        category       996       0.21      282852

# %%
interim_mart['asset_prod'].value_counts().head(10)
interim_mart['asset_prod'], uniques = pd.factorize(interim_mart['asset_prod'])

uniques
# Out:
# CategoricalIndex(['FOD', 'RVOD', 'SVOD'], categories=['FOD', 'RVOD', 'SVOD'], ordered=False, dtype='category')

# %%
from src.schema import ASSET_PROD_MAP

def encode_asset_prod(df: pd.DataFrame):
    df['asset_prod_code'] = (
        df['asset_prod']
        .map(ASSET_PROD_MAP)
        .fillna(-1)
        .astype("int8")
    )
    return df

# %%
interim_mart['screen_tp'].value_counts().head(10)
interim_mart['screen_tp'], uniques = pd.factorize(interim_mart['screen_tp'])

uniques
# Out:
# CategoricalIndex(['HD', 'SD', 'UHD'], categories=['HD', 'SD', 'UHD'], ordered=False, dtype='category')

# %%
def encode_screen_tp(df: pd.DataFrame):
    df['screen_tp_code'] = (
        df['screen_tp']
        .map(SCREEN_TP_MAP)
        .fillna(-1)
        .astype("int8")
    )
    return df

# %%
interim_mart['screen_tp'].unique()
# Out:
# array([ 0, -1,  1,  2])
